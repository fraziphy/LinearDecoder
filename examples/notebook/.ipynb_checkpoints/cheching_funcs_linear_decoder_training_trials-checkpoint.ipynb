# %%
import sys
import os
import numpy as np
import pickle
import matplotlib.pyplot as plt

# Add the parent directory of LinearDecoder to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from LinearDecoder import funcs
from scripts import generate_data
from scripts import plots

# %%
rng_decode = np.random.default_rng(np.random.SeedSequence(entropy=654321, spawn_key=(0, 1, 3, 1)))

# %%
# Set parameters
n_neurons = 10000
duration = 200  # ms
dt = 0.1  # ms
avg_rate = 30  # Hz

spike_1 = generate_data.dummy_spiketimes(n_neurons, duration, dt, avg_rate)

# %%
plots.plot_raster(spike_1)

# %%
# spikes_trials_all = []
# for trial in range(1,21):
#     filename = f"/Users/frazi/scripts/HLIF_6_mac/data/perturbed_simulations_V_th_std_{0.75}_trial_{trial}_session_{0}.pkl"
#     with open(filename, 'rb') as f:
#         data = pickle.load(f)
#     spike_1 = data["spikes"]
#     spikes_trials_all.append(spike_1)

# %%
spikes_trials_all = []
for trial in range(1,21):
    spike_1 = generate_data.dummy_spiketimes(n_neurons, duration, dt, avg_rate)
    spikes_trials_all.append(spike_1)

# %%
n_neurons = 10000
duration=200
dt=0.1
n_steps = int(duration / dt)
time = np.arange(n_steps) * dt

# Generate base sine wave with a period of 400 ms
frequency = 2.5  # 2.5 Hz for 400 ms period
base_sine = 2 * np.sin(2 * np.pi * frequency * time / 1000)

# Keep only the upper half of the sine wave
signal = np.maximum(base_sine, 0)

# %%
# Initialize
decoder = funcs.LinearDecoder(dt=0.1, tau=10, lambda_reg=1e-3, rng=np.random.default_rng(2))

# Preprocess data
filtered_spikes = decoder.preprocess_data(spikes_trials_all, n_neurons, duration)

# Perform stratified cross-validation
train_errors, test_errors, all_weights = decoder.stratified_cv(filtered_spikes, signal)

# Print results
print("Average Train RMSE:", train_errors.mean(axis=0))
print("Average Test RMSE:", test_errors.mean(axis=0))
# Out:
# Average Train RMSE: [0.01018511]
# Average Test RMSE: [0.50791484]

# %%
test_errors.std(axis=0)
# Out:
# array([0.04087518])

# %%
plt.plot(decoder.example_predicted_train[:,0])

# %%
plt.plot(decoder.example_predicted_test[:,0])

# %%
plt.plot(decoder.example_predicted_train[:,0])

# %%
np.array(all_weights[0]).ravel().mean()
# Out:
# 0.0004254147890304918

# %%
spike_matrices = np.array([funcs.spikes_to_matrix(trial_spikes, n_steps, n_neurons, dt) for trial_spikes in spikes_trials_all])

# %%
tau = 10
kernel = np.exp(-np.arange(0, 5 * tau, dt) / tau)
filtered_spikes_training_trials = funcs.filter_spikes_exp_kernel(spike_matrices, kernel)

# %%
time = np.arange(n_steps) * dt

# Generate base sine wave with a period of 400 ms
frequency = 2.5  # 2.5 Hz for 400 ms period
base_sine = 2 * np.sin(2 * np.pi * frequency * time / 1000)

# Keep only the upper half of the sine wave
signal1 = np.maximum(base_sine, 0)
signal2 = 4 * np.sin(4 * np.pi * frequency * time / 1000)

# %%
signal = np.append(signal1,signal2).reshape(2,n_steps)

# %%
plt.plot(signal[0],"r")
plt.plot(signal[1],"b")

# %%
w = funcs.linear_decoder_training_trials(rng_decode, filtered_spikes_training_trials, signal)

# %%
w.shape
# Out:
# (10000, 2)

# %%
y = filtered_spikes_training_trials.dot(w)
y.shape
# Out:
# (4, 2000, 2)

# %%
plt.plot(y[0,:,0],"r")
plt.plot(y[0,:,1],"b")

# %%
n_signals = 2
n_trials = 4

tiled_signal = np.tile(signal.T, (n_trials, 1))
tiled_signal.shape
# Out:
# (8000, 2)

# %%
plt.plot(tiled_signal[:,1])

# %%
(y.reshape(-1,2)-tiled_signal ==ah.reshape(-1,2)).all()
# Out:
# True

# %%
y.reshape(-1,2).shape
# Out:
# (8000, 2)

# %%
ah = (y-signal.T)

# %%
ah.shape
# Out:
# (4, 2000, 2)

# %%
(ah[0,:,1] == y[0,:,1] - signal[1]).all()
# Out:
# True

# %%
ah_m = np.sqrt(np.mean((ah)**2, axis=1), axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 ah_m = np.sqrt(np.mean((ah)**2, axis=1), axis=0)
#
# TypeError: sqrt() got an unexpected keyword argument 'axis'

# %%
n_signal = 2

# %%
np.sqrt(((y-signal.T)**2).reshape(-1,n_signal).mean(axis=0))
# Out:
# array([0.00236876, 0.00568001])

# %%
(filtered_spikes_training_trials[0].dot(w)).shape
# Out:
# (2000, 2)

# %%
filtered_spikes_training_trials[0].reshape(-1,2)
# Out:
# array([[ 2.27464661e-17,  6.82393984e-17],
#        [-9.09858645e-17, -3.98063157e-17],
#        [ 7.96126315e-17,  9.09858645e-17],
#        ...,
#        [-1.81971729e-16,  2.78756983e-02],
#        [ 2.12247974e-01,  1.95929574e-01],
#        [ 9.07400347e-01,  1.17959385e-02]])

# %%
a = np.array([[1,2,3,4]])
a.ndim
# Out:
# 2
